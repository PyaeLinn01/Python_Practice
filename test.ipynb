# %%
s = "bbbaaaba"
t = "aaabbbba"

sort_s = sorted(s)
sort_t = sorted(t)

print(sort_s)
print(sort_t)
type(s)
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b']
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b']
# list

# %%
num = 19

list_num = list(str(num))

for n in list_num:
    n = int(n)
    n1 += n ** 2
    print(n1)
# Out:
# 82
# 163

# %%
s = "leetcode"
sl = set(s)
print(sl)

sort = sorted(s)
print(sort)
# Out:
# {'d', 'e', 'l', 't', 'c', 'o'}
# ['c', 'd', 'e', 'e', 'e', 'l', 'o', 't']

# %%
num = 38
num = list(str(num))
first = []
for n in num:
    print(n)
    print(type(n))
# Out:
# 3
# <class 'str'>
# 8
# <class 'str'>

# %%
s = "hello world"
s = s.split()

last = s[-1]
last
# Out:
# 'world'

# %%
pow(16,0.5)
# Out:
# 4.0

# %%
num = 16
square_root = (num ** int(0.5))
print(square_root)
if type(square_root)== float:
    
    print(False) 
else:print(True)
# Out:
# 1
# True
