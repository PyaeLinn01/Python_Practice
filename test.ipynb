# %%
s = "bbbaaaba"
t = "aaabbbba"

sort_s = sorted(s)
sort_t = sorted(t)

print(sort_s)
print(sort_t)
type(s)
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b']
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b']
# list

# %%
num = 81
list_num = list(str(num))
print(list_num)
# Out:
# ['8', '1']
